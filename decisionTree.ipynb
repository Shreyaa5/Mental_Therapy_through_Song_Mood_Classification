# %% [markdown]
# Importing Necessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_curve, auc
import pickle

# %% [markdown]
# Loading Dataset

# %% [markdown]
# A - worry a lot or are in constant fear
# B - restless and irritable frequently
# C - difficulty in concentrating or making decisions
# D - muscle tension
# E - frequent panic attacks
# F - Sleep disturbed regularly
# G - heart palpitations, or do you sweat or tremble frequently
# H - constant physical pain and ache
# I - persistently feel low or sad or hopelessness
# J - fatigue, low energy and low motivation all the time
# K - significant change in your appetite recently
# L - gain or lost significant amount of weight in a short period of time recently
# M - suicidal thoughts, be it sometimes or frequently
# N - excessively increased energy or activity level
# O - frequent mood swings with heavy fluctuations
# P - you constantly taking reckless or impulsive decisions
# Q - frequent hallucinations or delusions
# R - isolate yourself from the society constantly
# S - thoughts disorganised
# T - difficulty in performing daily activitie
# U - frequent intrusive thoughts
# V - any regular repetitive behaviour in your daily life
# W - feel anxious regularly
# X - frequent flashbacks
# Y - actively trying to avoid reminders of trauma
# Z - detached or numb frequently
# AB - highly alert about your surroundings
#
# 1 - ANXIETY DISORDER
# 2 - DEPRESSION
# 3 - BIPOLAR DISORDER
# 4 - SCHIZOPHRENIA
# 5 - OCD
# 6 - PTSD

# %%
data = pd.read_csv("dataset.csv")

# %% [markdown]
# Splitting into train and test set

# %%
X = data.iloc[:,0:27]
y = data.iloc[:,27]
#X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %% [markdown]
# Calling the model class and fitting the data

# %%
decisionTree = DecisionTreeClassifier()
dt = decisionTree.fit(X,y)

# %%
#decisionTree.predict(X_test)

# %%
#decisionTree.score(X_test,y_test)

# %%
tree.plot_tree(dt)
# Out:
# [Text(0.5555555555555556, 0.875, 'x[3] <= 0.5\ngini = 0.833\nsamples = 6\nvalue = [1, 1, 1, 1, 1, 1]'),
#  Text(0.3333333333333333, 0.625, 'x[12] <= 0.5\ngini = 0.667\nsamples = 3\nvalue = [0, 1, 1, 1, 0, 0]'),
#  Text(0.4444444444444444, 0.75, 'True  '),
#  Text(0.2222222222222222, 0.375, 'x[2] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.1111111111111111, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3333333333333333, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.4444444444444444, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.7777777777777778, 0.625, 'x[16] <= 0.5\ngini = 0.667\nsamples = 3\nvalue = [1, 0, 0, 0, 1, 1]'),
#  Text(0.6666666666666667, 0.75, '  False'),
#  Text(0.6666666666666666, 0.375, 'x[5] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 0, 1, 0]'),
#  Text(0.5555555555555556, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
# ...

# %%
pickle.dump(decisionTree, open('model1.pkl','wb'))

# %%
from joblib import dump, load

# %%
dump(decisionTree,'model.sav')
# Out:
# ['model.sav']

# %%
md = load('model.sav')

# %%
import joblib
import sklearn
print("Joblib version:", joblib.__version__)
print("Scikit-learn version:", sklearn.__version__)
# Out:
# Joblib version: 1.4.2
# Scikit-learn version: 1.5.1
